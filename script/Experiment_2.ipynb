# %% [markdown]
# # Step 4 : BN <-> EN CLIR

# %%
# !pip install transformers sentencepiece sacremoses
# Out:
# Collecting transformers
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp39-cp39-win_amd64.whl.metadata (10 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting filelock (from transformers)
#   Using cached filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.11.3-cp39-cp39-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from transformers) (4.67.1)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Collecting click (from sacremoses)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from sacremoses) (1.5.3)
# Requirement already satisfied: colorama in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\miniconda3\envs\clir_env\lib\site-packages (from requests->transformers) (2025.11.12)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Downloading sentencepiece-0.2.1-cp39-cp39-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.5/1.1 MB 243.2 kB/s eta 0:00:03
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ----------------------------- ---------- 0.8/1.1 MB 205.8 kB/s eta 0:00:02
#    ---------------------------------------- 1.1/1.1 MB 112.5 kB/s  0:00:08
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/897.5 kB ? eta -:--:--
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------- ---------------- 524.3/897.5 kB 76.6 kB/s eta 0:00:05
#    ---------------------------------- ---- 786.4/897.5 kB 76.4 kB/s eta 0:00:02
#    ---------------------------------- ---- 786.4/897.5 kB 76.4 kB/s eta 0:00:02
#    ---------------------------------- ---- 786.4/897.5 kB 76.4 kB/s eta 0:00:02
#    ---------------------------------- ---- 786.4/897.5 kB 76.4 kB/s eta 0:00:02
#    ---------------------------------- ---- 786.4/897.5 kB 76.4 kB/s eta 0:00:02
#    ---------------------------------------- 897.5/897.5 kB 79.9 kB/s  0:00:10
# Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading regex-2025.11.3-cp39-cp39-win_amd64.whl (277 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached filelock-3.19.1-py3-none-any.whl (15 kB)
# Installing collected packages: sentencepiece, safetensors, regex, fsspec, filelock, click, sacremoses, huggingface-hub, tokenizers, transformers
#
#    ---- -----------------------------------  1/10 [safetensors]
#    -------- -------------------------------  2/10 [regex]
#    ------------ ---------------------------  3/10 [fsspec]
#    ------------ ---------------------------  3/10 [fsspec]
#    ------------ ---------------------------  3/10 [fsspec]
#    ---------------- -----------------------  4/10 [filelock]
#    -------------------- -------------------  5/10 [click]
#    ------------------------ ---------------  6/10 [sacremoses]
#    ------------------------ ---------------  6/10 [sacremoses]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [huggingface-hub]
#    -------------------------------- -------  8/10 [tokenizers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ---------------------------------------- 10/10 [transformers]
#
# Successfully installed click-8.1.8 filelock-3.19.1 fsspec-2025.10.0 huggingface-hub-0.36.0 regex-2025.11.3 sacremoses-0.1.1 safetensors-0.7.0 sentencepiece-0.2.1 tokenizers-0.22.1 transformers-4.57.3

# %%
# !pip -q install torch

# %% [markdown]
# ## 4.2 Load Saved BM25 Indexes (use Step 3 Files)

# %%
import pickle
import re

def load_index(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

en_pack = load_index('bm25_en.pkl')
bn_pack = load_index('bm25_bn.pkl')

bm25_en = en_pack['bm25']
doc_ids_en = en_pack['doc_ids']
docs_en = en_pack['docs']

bm25_bn = bn_pack['bm25']
doc_ids_bn = bn_pack['doc_ids']
docs_bn = bn_pack['docs']


def tokenize_en(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text.split()

def tokenize_bn(text):
    text = re.sub(r'\s+', ' ', text).strip()
    return text.split()

def search_en(query, top_k=5):
    q = tokenize_en(query)
    scores = bm25_en.get_scores(q)
    idx = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:top_k]
    return [{"doc_id": doc_ids_en[i], "score": float(scores[i]), "title": docs_en[i].get("title",""), "url": docs_en[i].get("url","")} for i in idx]

def search_bn(query, top_k=5):
    q = tokenize_bn(query)
    scores = bm25_bn.get_scores(q)
    idx = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:top_k]
    return [{"doc_id": doc_ids_bn[i], "score": float(scores[i]), "title": docs_bn[i].get("title",""), "url": docs_bn[i].get("url","")} for i in idx]

print("Index loaded:" , len(docs_en), "English documents and", len(docs_bn), "Bengali documents.")
# Out:
# Index loaded: 124 English documents and 142 Bengali documents.

# %% [markdown]
# ## 4.2 Language Detection (BN vs EN)

# %%
def is_bangla(text):
    for ch in text:
        o = ord(ch) #unicode of bangla
        if 0x0980 <= o <= 0x09FF:
            return True
    return False

# %%
is_bangla("এই একটি বাংলা বাক্য।")
# Out:
# True

# %%
is_bangla("সাদিয়া")
# Out:
# True

# %%
is_bangla("this is an english sentence.")
# Out:
# False

# %% [markdown]
# ## Load BN <-> EN translation model (MarianMT / OPUS MT)

# %%
from transformers import MarianMTModel, MarianTokenizer
# BN_EN_NAME = 'Helsinki-NLP/opus-mt-bn-en'
# EN_BN_NAME = 'shhossain/opus-mt-en-bn'
BN_EN_NAME = "Helsinki-NLP/opus-mt-bn-en"
EN_BN_NAME = "shhossain/opus-mt-en-to-bn"

tok_bn_en = MarianTokenizer.from_pretrained(BN_EN_NAME)
mod_bn_en = MarianMTModel.from_pretrained(BN_EN_NAME)

tok_en_bn = MarianTokenizer.from_pretrained(EN_BN_NAME)
mod_en_bn = MarianMTModel.from_pretrained(EN_BN_NAME)

def translate_bn_to_en(text):
    batch = tok_bn_en([text], return_tensors="pt",padding=True, truncation=True)
    gen = mod_bn_en.generate(**batch, max_new_tokens=128)
    return tok_bn_en.batch_decode(gen, skip_special_tokens=True)[0]


def translate_en_to_bn(text):
    batch = tok_en_bn([text], return_tensors="pt",padding=True, truncation=True)
    gen = mod_en_bn.generate(**batch, max_new_tokens=128)
    return tok_en_bn.batch_decode(gen, skip_special_tokens=True)[0]

print("Translation models loaded.")
# Out:
# Translation models loaded.

# %%
print(translate_bn_to_en("বাংলাদেশ একটি সুন্দর দেশ।"))
print(translate_en_to_bn("Bangladesh is a beautiful country."))
# Out:
# Bangladesh is a beautiful country.
# বাংলাদেশ একটি সুন্দর দেশ।

# %% [markdown]
# ## 4.4 CLIR search function

# %%
def clir_search(query, top_k=5):
    if is_bangla(query):
        q_en = translate_bn_to_en(query)
        results_bn = search_bn(query, top_k)
        results_en = search_en(q_en, top_k)
        return_en = {"queary_language": "bn", "translated_query": q_en, "results_language": "en", "results": results_en}
        return_bn = {"queary_language": "bn", "translated_query": q_en, "results_language": "bn", "results": results_bn}
        return return_bn,return_en
    else:
        q_bn = translate_en_to_bn(query)
        results_en = search_en(query, top_k)
        results_bn = search_bn(q_bn, top_k)
        return_bn = {"queary_language": "en", "translated_query": q_bn, "results_language": "bn", "results": results_bn}
        return_en = {"queary_language": "en", "translated_query": q_bn, "results_language": "en", "results": results_en}
        return return_bn,return_en

# %% [markdown]
# ## 4.5 Test

# %%
query_key= "বাংলাদেশ ক্রিকেট"
out = clir_search(query_key, top_k=5)


for r in out['results']:
    print(r['title'],"-", r['url'])
    print("____________________________________________")
# Out:
# Detected Bengali query. Translating to English for search...
# Translated Query: Bangladesh Cricket
# {'query_language': 'bn', 'translated_query': 'Bangladesh Cricket', 'results_language': 'en', 'results': [{'doc_id': 'en_000060', 'score': 7.069326487412225, 'title': 'bangladesh cricket board (bcb) has decided to start a new age-level tournament called rising stars u-23 cricket tournament, bcb officials informed after a board meeting on wednesday. the board meeting which started at 11 am, went on till evening before a media brief took place at 7:30 pm.', 'url': 'https://www.thedailystar.net/sports/cricket/news/bcb-introduce-new-age-group-u-23-tournament-4065501'}, {'doc_id': 'en_000116', 'score': 6.832835626336079, 'title': 'the bangladesh cricket board (bcb) yesterday named 28-year-old wicketkeeper-batter nurul hasan sohan captain for the t20i series in zimbabwe after deciding to rest regular skipper mahmudullah riyad for the t20is.', 'url': 'https://www.thedailystar.net/sports/cricket/news/sohan-captain-zim-t20is-3077041'}, {'doc_id': 'en_000050', 'score': 6.636383222097057, 'title': 'a bangladesh cricket board (bcb) official on thursday said that the board has taken over the chattogram royals franchise following a withdrawal letter submitted by the franchise owner, just a day before the start of the 12th edition of the bangladesh premier league (bpl).', 'url': 'https://www.thedailystar.net/sports/sports-special/bpl-2026/news/bcb-takes-over-chattogram-franchise-after-owners-withdrawal-letter-4065916'}, {'doc_id': 'en_000158', 'score': 6.301082848291724, 'title': 'former bangladesh women’s cricket team captain jahanara alam’s recent allegations of sexual harassment have sparked widespread discussion in the country’s sporting community. while women athletes in bangladesh continue to face various forms of harassment, many remain hesitant to speak out -- largely due to the absence of a secure and supportive environment.', 'url': 'https://www.thedailystar.net/star-multimedia/sports-multimedia/news/when-will-women-athletes-get-safe-space-bangladesh-4032581'}, {'doc_id': 'en_000062', 'score': 4.072619483652301, 'title': 'virat kohli marked his return to domestic cricket in emphatic fashion as he shattered a long-standing record on his first outing in the vijay hazare trophy, while rohit sharma also made headlines with a blistering century-plus knock on the same day.', 'url': 'https://www.thedailystar.net/sports/cricket/news/kohli-breaks-tendulkar-record-vijay-hazare-return-rohit-joins-150-plus-club-4065416'}]}
# bangladesh cricket board (bcb) has decided to start a new age-level tournament called rising stars u-23 cricket tournament, bcb officials informed after a board meeting on wednesday. the board meeting which started at 11 am, went on till evening before a media brief took place at 7:30 pm. - https://www.thedailystar.net/sports/cricket/news/bcb-introduce-new-age-group-u-23-tournament-4065501
# ____________________________________________
# the bangladesh cricket board (bcb) yesterday named 28-year-old wicketkeeper-batter nurul hasan sohan captain for the t20i series in zimbabwe after deciding to rest regular skipper mahmudullah riyad for the t20is. - https://www.thedailystar.net/sports/cricket/news/sohan-captain-zim-t20is-3077041
# ____________________________________________
# a bangladesh cricket board (bcb) official on thursday said that the board has taken over the chattogram royals franchise following a withdrawal letter submitted by the franchise owner, just a day before the start of the 12th edition of the bangladesh premier league (bpl). - https://www.thedailystar.net/sports/sports-special/bpl-2026/news/bcb-takes-over-chattogram-franchise-after-owners-withdrawal-letter-4065916
# ____________________________________________
# former bangladesh women’s cricket team captain jahanara alam’s recent allegations of sexual harassment have sparked widespread discussion in the country’s sporting community. while women athletes in bangladesh continue to face various forms of harassment, many remain hesitant to speak out -- largely due to the absence of a secure and supportive environment. - https://www.thedailystar.net/star-multimedia/sports-multimedia/news/when-will-women-athletes-get-safe-space-bangladesh-4032581
# ____________________________________________
# virat kohli marked his return to domestic cricket in emphatic fashion as he shattered a long-standing record on his first outing in the vijay hazare trophy, while rohit sharma also made headlines with a blistering century-plus knock on the same day. - https://www.thedailystar.net/sports/cricket/news/kohli-breaks-tendulkar-record-vijay-hazare-return-rohit-joins-150-plus-club-4065416
# ____________________________________________

# %%
query_key= "বাংলাদেশ ক্রিকেট"
out_bn, out_en = clir_search(query_key, top_k=5)

print("Print result in Bangla:")
for r in out_bn['results']:
    print(r['title'],"-", r['url'],r['score'])
    print("____________________________________________")


print("Result in English:")
for r in out_en['results']:
    print(r['title'],"-", r['url'],r['score'])
    print("____________________________________________")
# Out:
# Print result in Bangla:
# ঢাকায় পৌঁছেছে শহীদ শরিফ ওসমান হাদির মরদেহ - https://bangladeshdiplomat.com/11050/latest/%e0%a6%a2%e0%a6%be%e0%a6%95%e0%a6%be%e0%a6%af%e0%a6%bc-%e0%a6%aa%e0%a7%8c%e0%a6%81%e0%a6%9b%e0%a7%87%e0%a6%9b%e0%a7%87-%e0%a6%b6%e0%a6%b9%e0%a7%80%e0%a6%a6-%e0%a6%b6%e0%a6%b0%e0%a6%bf%e0%a6%ab/ 1.7379079414714855
# ____________________________________________
# সপরিবারে লন্ডন থেকে দেশের পথে তারেক রহমান - https://www.risingbd.com/politics/news/633345 1.7151871091754434
# ____________________________________________
# স্বদেশ প্রত্যাবর্তনে তারেক রহমানকে স্বাগত জানিয়েছে ডিবিএ - https://www.risingbd.com/economics/stock-market/633295 1.6223062411528448
# ____________________________________________
# ‘বয়কট বাংলাদেশ’ পোস্টার শিলিগুড়ির হোটেল গাড়ি ট্যাক্সিতে - https://www.risingbd.com/international/news/633288 1.570339150955638
# ____________________________________________
# বাংলাদেশ আর কখনো আধিপত্যবাদী শক্তির কাছে মাথা নত করবে না: মঞ্জু - https://www.risingbd.com/bangladesh/news/633337 1.5345884317629432
# ____________________________________________
# Result in English:
# bangladesh cricket board (bcb) has decided to start a new age-level tournament called rising stars u-23 cricket tournament, bcb officials informed after a board meeting on wednesday. the board meeting which started at 11 am, went on till evening before a media brief took place at 7:30 pm. - https://www.thedailystar.net/sports/cricket/news/bcb-introduce-new-age-group-u-23-tournament-4065501 7.069326487412225
# ____________________________________________
# the bangladesh cricket board (bcb) yesterday named 28-year-old wicketkeeper-batter nurul hasan sohan captain for the t20i series in zimbabwe after deciding to rest regular skipper mahmudullah riyad for the t20is. - https://www.thedailystar.net/sports/cricket/news/sohan-captain-zim-t20is-3077041 6.832835626336079
# ____________________________________________
# a bangladesh cricket board (bcb) official on thursday said that the board has taken over the chattogram royals franchise following a withdrawal letter submitted by the franchise owner, just a day before the start of the 12th edition of the bangladesh premier league (bpl). - https://www.thedailystar.net/sports/sports-special/bpl-2026/news/bcb-takes-over-chattogram-franchise-after-owners-withdrawal-letter-4065916 6.636383222097057
# ____________________________________________
# former bangladesh women’s cricket team captain jahanara alam’s recent allegations of sexual harassment have sparked widespread discussion in the country’s sporting community. while women athletes in bangladesh continue to face various forms of harassment, many remain hesitant to speak out -- largely due to the absence of a secure and supportive environment. - https://www.thedailystar.net/star-multimedia/sports-multimedia/news/when-will-women-athletes-get-safe-space-bangladesh-4032581 6.301082848291724
# ____________________________________________
# virat kohli marked his return to domestic cricket in emphatic fashion as he shattered a long-standing record on his first outing in the vijay hazare trophy, while rohit sharma also made headlines with a blistering century-plus knock on the same day. - https://www.thedailystar.net/sports/cricket/news/kohli-breaks-tendulkar-record-vijay-hazare-return-rohit-joins-150-plus-club-4065416 4.072619483652301
# ____________________________________________

# %%
out
# Out:
# {'query_language': 'en',
#  'translated_query': 'বাংলাদেশ ক্রিকেট',
#  'results_language': 'bn',
#  'results': [{'doc_id': 'ba_000129',
#    'score': 1.7379079414714855,
#    'title': 'ঢাকায় পৌঁছেছে শহীদ শরিফ ওসমান হাদির মরদেহ',
#    'url': 'https://bangladeshdiplomat.com/11050/latest/%e0%a6%a2%e0%a6%be%e0%a6%95%e0%a6%be%e0%a6%af%e0%a6%bc-%e0%a6%aa%e0%a7%8c%e0%a6%81%e0%a6%9b%e0%a7%87%e0%a6%9b%e0%a7%87-%e0%a6%b6%e0%a6%b9%e0%a7%80%e0%a6%a6-%e0%a6%b6%e0%a6%b0%e0%a6%bf%e0%a6%ab/'},
#   {'doc_id': 'ba_000033',
#    'score': 1.7151871091754434,
#    'title': 'সপরিবারে লন্ডন থেকে দেশের পথে তারেক রহমান',
#    'url': 'https://www.risingbd.com/politics/news/633345'},
#   {'doc_id': 'ba_000083',
#    'score': 1.6223062411528448,
#    'title': 'স্বদেশ প্রত্যাবর্তনে তারেক রহমানকে স্বাগত জানিয়েছে ডিবিএ',
#    'url': 'https://www.risingbd.com/economics/stock-market/633295'},
#   {'doc_id': 'ba_000090',
#    'score': 1.570339150955638,
#    'title': '‘বয়কট বাংলাদেশ’ পোস্টার শিলিগুড়ির হোটেল গাড়ি ট্যাক্সিতে',
#    'url': 'https://www.risingbd.com/international/news/633288'},
#   {'doc_id': 'ba_000041',
#    'score': 1.5345884317629432,
#    'title': 'বাংলাদেশ আর কখনো আধিপত্যবাদী শক্তির কাছে মাথা নত করবে না: মঞ্জু',
#    'url': 'https://www.risingbd.com/bangladesh/news/633337'}]}
